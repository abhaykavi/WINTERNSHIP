# %%
rdd=sc.textFile("/FileStore/tables/ELEC_PERF.txt")
rdd.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [&#39;4JN18CS001,AASHUTOSH,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,64,35&#39;,
#  &#39;4JN18CS002,AAUSHI,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,46,80&#39;,
#  &#39;4JN18CS003,ABDUL NAAFE,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,82,64&#39;,
#  &#39;4JN18CS004,ABHANG,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,46,66&#39;,
#  &#39;4JN18CS005,AISWARYA S SARANGAPANI,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,61,5&#39;,
#  &#39;4JN18CS006,AKINAPALLI VIVEK VINAY VARDHAN,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,18,11&#39;,
#  &#39;4JN18CS007,ALAMELU,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,88,50&#39;,
#  &#39;4JN18CS008,ANANTHAN,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,60,82&#39;,
#  &#39;4JN18CS009,ARWA,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,16,96&#39;,
#  &#39;4JN18CS010,ASMA SULTANA,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,20,41&#39;,
#  &#39;4JN18CS011,ASWATHI RAVI,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,9,46&#39;,
#  &#39;4JN18CS012,ATHREYDATH V C,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,74,23&#39;,
#  &#39;4JN18CS013,BANSARI,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,75,52&#39;,
#  &#39;4JN18CS014,BHAGIRATHI,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,41,52&#39;,
#  &#39;4JN18CS015,BHANUPRAKASH KN,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,40,27&#39;,
#  &#39;4JN18CS016,BRENDEN,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,68,54&#39;,
#  &#39;4JN18CS017,CHINCHU C,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,57,89&#39;,
#  &#39;4JN18CS018,CHINTA ,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,43,20&#39;,
#  &#39;4JN18CS019,CIJO,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,5,78&#39;,
#  &#39;4JN18CS020,DANABOINA VISHNU VARDHAN,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,98,58&#39;,
#  &#39;4JN18CS021,DARSHAK TARAK MADHANI,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,41,12&#39;,
#  &#39;4JN18CS022,DATTAATRAYA,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,66,38&#39;,
#  &#39;4JN18CS023,DHANIREDDY,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,10,14&#39;,
#  &#39;4JN18CS024,DURSHETTI,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,77,38&#39;,
#  &#39;4JN18CS025,FAJILA T P,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,39,29&#39;,
#  &#39;4JN18CS026,GEETHANJALI J BHAT,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,8,24&#39;,
#  &#39;4JN18CS027,GOPISINGH,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,62,77&#39;,
#  &#39;4JN18CS028,GUFRAN,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,40,95&#39;,
#  &#39;4JN18CS029,HARMANPREET,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,89,43&#39;,
#  &#39;4JN18CS030,ISHNEET,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,19,64&#39;,
#  &#39;4JN18CS031,IYAPPAN V,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,62,70&#39;,
#  &#39;4JN18CS032,JACOB,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,77,52&#39;,
#  &#39;4JN18CS033,JAFER SADIQUE HUSSAIN SHAIKH,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,50,2&#39;,
#  &#39;4JN18CS034,JAMPALA,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,79,44&#39;,
#  &#39;4JN18CS035,JAWALA,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,71,4&#39;,
#  &#39;4JN18CS036,JOREPALLI,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,15,71&#39;,
#  &#39;4JN18CS037,KAILASHBEN,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,71,42&#39;,
#  &#39;4JN18CS038,KALYANI RADHIKA,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,66,94&#39;,
#  &#39;4JN18CS039,KANCHARLA NAGA KRISHNA PAVAN,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,57,1&#39;,
#  &#39;4JN18CS040,KARANAM MANI KUMAR,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,60,30&#39;,
#  &#39;4JN18CS041,KARTHIK INV,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,42,98&#39;,
#  &#39;4JN18CS042,KATTAMREDDY,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,85,33&#39;,
#  &#39;4JN18CS043,KAVITA,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,39,12&#39;,
#  &#39;4JN18CS044,KODURU,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,50,75&#39;,
#  &#39;4JN18CS045,KOMAL BHOOTRA,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,44,85&#39;,
#  &#39;4JN18CS046,KRISHNAKUMAR,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,5,42&#39;,
#  &#39;4JN18CS047,KURUVA,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,23,81&#39;,
#  &#39;4JN18CS048,LAVISH,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,48,19&#39;,
#  &#39;4JN18CS049,LAXMI K S,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,48,4&#39;,
#  &#39;4JN18CS050,MADAN,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,33,94&#39;,
#  &#39;4JN18CS051,MAHIKA,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,89,91&#39;,
#  &#39;4JN18CS052,MALINI M,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,88,73&#39;,
#  &#39;4JN18CS053,MANYAM RAMA KRISHNA KISHORE,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,26,10&#39;,
#  &#39;4JN18CS054,MARYLAL SHAJI,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,80,35&#39;,
#  &#39;4JN18CS055,MOHDZAINAHMED,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,46,87&#39;,
#  &#39;4JN18CS056,MUNEESWARA,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,7,86&#39;,
#  &#39;4JN18CS057,NALLA SARITHA,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,15,40&#39;,
#  &#39;4JN18CS058,NAVEEN S,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,41,81&#39;,
#  &#39;4JN18CS059,NAVJIT,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,13,25&#39;,
#  &#39;4JN18CS060,NEHA PRABHU,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,19,89&#39;,
#  &#39;4JN18CS061,NELAPUDI,15CS744-UNIX SYSTEM PROGRAMMING,15CS753-DIGITAL IMAGE PROCESSING,91,64&#39;,
#  &#39;4JN18CS062,NELLIPALLI,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,80,3&#39;,
#  &#39;4JN18CS063,NIDHA,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,74,32&#39;,
#  &#39;4JN18CS064,NIKHILA,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,24,18&#39;,
#  &#39;4JN18CS065,PASAM VENKATA MADHU SUDHAN,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,12,62&#39;,
#  &#39;4JN18CS066,PINKEY,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,5,53&#39;,
#  &#39;4JN18CS067,PRASHON,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,92,64&#39;,
#  &#39;4JN18CS068,PRIYANKA B M,15CS744-UNIX SYSTEM PROGRAMMING,15CS754-STORAGE AREA NETWORKS,9,20&#39;,
#  &#39;4JN18CS069,PUSHPALATHA,15CS743-INFORMATION AND NETWORK SECURITY,15CS754-STORAGE AREA NETWORKS,92,64&#39;,
#  &#39;4JN18CS070,QUEYA,15CS743-INFORMATION AND NETWORK SECURITY,15CS753-DIGITAL IMAGE PROCESSING,63,85&#39;,
#  &#39;4JN18CS071,RAGHAVENDRA B P,15CS743-INFORMAT

# %%
rdd2=rdd.map(lambda a:a.split(','))
#rdd2.take(5)
rdd2_elec1=rdd2.map(lambda x: (x[2],1))
print(rdd2_elec1.reduceByKey(lambda x,y: x+y).map(lambda x:(x[1],x[0])).sortByKey(False).collect())
rdd2_elec2=rdd2.map(lambda x: (x[3],1))
print(rdd2_elec2.reduceByKey(lambda x,y: x+y).map(lambda x:(x[1],x[0])).sortByKey(False).collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(58, &#39;15CS743-INFORMATION AND NETWORK SECURITY&#39;), (42, &#39;15CS744-UNIX SYSTEM PROGRAMMING&#39;)]
# [(50, &#39;15CS754-STORAGE AREA NETWORKS&#39;), (50, &#39;15CS753-DIGITAL IMAGE PROCESSING&#39;)]
# </div>

# %%
rdd2_comb=rdd2.map(lambda x: ((x[2],x[3]),1))
#print(rdd2_comb.collect())
rdd3=rdd2_comb.reduceByKey(lambda x,y: x+y).map(lambda x:(x[1],x[0])).sortByKey(False)
print(rdd3.collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(30, (&#39;15CS743-INFORMATION AND NETWORK SECURITY&#39;, &#39;15CS753-DIGITAL IMAGE PROCESSING&#39;)), (28, (&#39;15CS743-INFORMATION AND NETWORK SECURITY&#39;, &#39;15CS754-STORAGE AREA NETWORKS&#39;)), (22, (&#39;15CS744-UNIX SYSTEM PROGRAMMING&#39;, &#39;15CS754-STORAGE AREA NETWORKS&#39;)), (20, (&#39;15CS744-UNIX SYSTEM PROGRAMMING&#39;, &#39;15CS753-DIGITAL IMAGE PROCESSING&#39;))]
# </div>

# %%
import statistics
rdd4_elec1=rdd2.map(lambda x: (x[2],int(x[4])))
rdd4_elec1_grouped=rdd4_elec1.groupByKey()
print(list((j[0], statistics.mean(list(j[1]))) for j in rdd4_elec1_grouped.collect()))
print(list((j[0], statistics.stdev(list(j[1]))) for j in rdd4_elec1_grouped.collect()))
rdd4_elec2=rdd2.map(lambda x: (x[3],int(x[5])))
rdd4_elec2_grouped=rdd4_elec2.groupByKey()
print(list((j[0], statistics.mean(list(j[1]))) for j in rdd4_elec2_grouped.collect()))
print(list((j[0], statistics.stdev(list(j[1]))) for j in rdd4_elec2_grouped.collect()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;15CS744-UNIX SYSTEM PROGRAMMING&#39;, 46.57142857142857), (&#39;15CS743-INFORMATION AND NETWORK SECURITY&#39;, 47.62068965517241)]
# [(&#39;15CS744-UNIX SYSTEM PROGRAMMING&#39;, 27.951301603396608), (&#39;15CS743-INFORMATION AND NETWORK SECURITY&#39;, 29.062441902575785)]
# [(&#39;15CS754-STORAGE AREA NETWORKS&#39;, 50.04), (&#39;15CS753-DIGITAL IMAGE PROCESSING&#39;, 48.24)]
# [(&#39;15CS754-STORAGE AREA NETWORKS&#39;, 29.60002757858616), (&#39;15CS753-DIGITAL IMAGE PROCESSING&#39;, 28.22617109517119)]
# </div>

# %%
rdd5=rdd2.map(lambda x: ((x[2],x[3]),(int(x[4]),int(x[5]))))
rdd5_grouped=rdd5.groupByKey()
print(list((j[0], statistics.mean(list(map(sum,j[1])))) for j in rdd5_grouped.collect()))
print(list((j[0], statistics.stdev(list(map(sum,j[1])))) for j in rdd5_grouped.collect()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[((&#39;15CS744-UNIX SYSTEM PROGRAMMING&#39;, &#39;15CS754-STORAGE AREA NETWORKS&#39;), 94.86363636363636), ((&#39;15CS743-INFORMATION AND NETWORK SECURITY&#39;, &#39;15CS754-STORAGE AREA NETWORKS&#39;), 100.96428571428571), ((&#39;15CS743-INFORMATION AND NETWORK SECURITY&#39;, &#39;15CS753-DIGITAL IMAGE PROCESSING&#39;), 91.96666666666667), ((&#39;15CS744-UNIX SYSTEM PROGRAMMING&#39;, &#39;15CS753-DIGITAL IMAGE PROCESSING&#39;), 97.95)]
# [((&#39;15CS744-UNIX SYSTEM PROGRAMMING&#39;, &#39;15CS754-STORAGE AREA NETWORKS&#39;), 38.84192071969157), ((&#39;15CS743-INFORMATION AND NETWORK SECURITY&#39;, &#39;15CS754-STORAGE AREA NETWORKS&#39;), 43.92795629112905), ((&#39;15CS743-INFORMATION AND NETWORK SECURITY&#39;, &#39;15CS753-DIGITAL IMAGE PROCESSING&#39;), 43.8370677138324), ((&#39;15CS744-UNIX SYSTEM PROGRAMMING&#39;, &#39;15CS753-DIGITAL IMAGE PROCESSING&#39;), 46.38792379148059)]
# </div>

# %%
rdd4_elec1_grouped.collect()
rdd4_elec2_grouped.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[88]: [(&#39;15CS754-STORAGE AREA NETWORKS&#39;,
#   &lt;pyspark.resultiterable.ResultIterable at 0x7f6960021cc0&gt;),
#  (&#39;15CS753-DIGITAL IMAGE PROCESSING&#39;,
#   &lt;pyspark.resultiterable.ResultIterable at 0x7f695fbf17b8&gt;)]</div>
